# %% [markdown]
# ### Scraping quotes images from inspirational quotes website

# %%
import os
import bs4
import requests

# %%
str = input()
input_str = str
str = str.replace(" ", "&20")

str
# Out:
# oneplus 9r
# 'oneplus&209r'

# %%
url = "https://www.snapdeal.com/search?keyword={}&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy".format(str)

# %%
print(url)
response = requests.get(url)
# Out:
# https://www.snapdeal.com/search?keyword=oneplus&209r&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n\t<!--[if IE 8]><html lang="en" class="ie ie8 lt-ie9 lt-ie10"> <![endif]-->\n<!--[if IE 9]><html lang="en" class="ie ie9 lt-ie10"> <![endif]-->\n<!--[if IE]><html lang="en" class="ie"><![endif]-->\n<!--[if gt IE 9]><!--><html lang="en"><!--<![endif]-->\n\t<head prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb# snapdeallog: https://ogp.me/ns/fb/snapdeallog#">\n\t\t<link rel="dns-prefetch" href="https://i1.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://i2.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://i3.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://i4.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://n1.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://n2.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://n3.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://n4.sdlcdn.com" />\r\n\t<link rel="dns-prefetch" href="https://sa.snapdeal.com" />\r\n\t<link rel="dns-prefetch" href="https://search-suggester.snapdeal.com" />\r\n\t<link rel="dns-prefetch" href="https://mobileapi.snapdeal.com" />\r\n<link rel="manifest" href="/manifest.json">\n\t\t<link rel="preload" href="https://i3.sdlcdn.com/js/1628254298266/snap/base.jquery111.min.js" crossorigin="anonymous" as="script">\n\t\t<link href="https://i3.sdlcdn.com/css/1628254298266/snap/common/scss/base.min.css" rel="stylesheet" type="text/css" />\n\t\t<link type="application/opensearchdescription+xml" rel="search" href="https://www.snapdeal.com/opensearch.xml"/>\r\n<link rel="publisher" href="https://plus.google.com/+snapdeal"/> \r\n<link rel="alternate" media="handheld" href="https://m.snapdeal.com/search"/>\r\n\t\t<link rel="shortcut icon" href="https://www.snapdeal.com/img/icons/finalFavicon.ico" type="image/x-icon" />\r\n<link rel=icon type=image/ico href="https://www.snapdeal.com/img/icons/finalFavicon.ico" />\r\n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta name="google-site-verification" content="wOEx6eudvpoTmmIuJw96ugPyq-TH_199kxmE9YqUQNM" />\r\n<meta name="msvalidate.01" content="431A1F370506446F4F451D7B16EE166C" />\r\n<meta name="y_key" content="b8b20c3f440781c8" />\r\n<meta name="format-detection" content="telephone=no" />\r\n<meta charset="utf-8"><title>Snapdeal.com - Online shopping India- Discounts - shop Online Perfumes, Watches, sunglasses etc</title>\n\t\t\n\t\t<meta name="description"\n\t\t\tcontent="Shop online & get great discounts on perfumes, watches, gifts, mobiles accessories, Digital Cameras, sunglasses & more at snapdeal.com. Get great deals on online shopping in India on various products & best prices in your city."/>\n\t<meta name="keywords"\n\t\t\tcontent="Online shopping India, Best buy, buy perfumes, sunglasses, digital cameras, mobiles handsets, DVD player, pendant, clothes, mobiles, gifts, discounts, shopping online, best deals, discount shopping, shop online, online bargaining.   "/>\n        \n         <meta name="twitter:card" content="app">\n         <meta name="twitter:app:country" content="IN"/>\n         <meta name="twitter:app:name:iphone" content="Snapdeal"/>\n         <meta name="twitter:app:id:iphone" content="721124909"/>\n         <meta name="twitter:app:name:ipad" content="Snapdeal"/>\n         <meta name="twitter:app:id:ipad" content="721124909"/>\n         <meta name="twitter:app:name:googleplay" content="Snapdeal"/>\n         <meta name="twitter:app:id:googleplay" content="com.snapdeal.main"/>\n         <meta name="twitter:app:url:iphone" content="snapdeal://m.snapdeal.com/acors/getCategoryListingPage">\n         <meta name="twitter:app:url:ipad" content="snapdeal://m.snapdeal.com/acors/getCategoryListingPage">\n         <meta name="twitter:app:url:googleplay" content="snapdeal://m.snapdeal.com/acors/getCategoryListingPage">\n         <meta property="fb:app_id" content="689277371113314" />\n         <meta property="og:type"   content="snapdeallog:item" />\n         <meta property="og:description" content="" />\n         <m ...

# %%
# HTML Parser --> parsed html into python object
soup = bs4.BeautifulSoup(response.content)

# %%
picture_element = soup.findAll('picture')

# %%
print(len(picture_element))
picture = picture_element[0]
print(picture_element)
# Out:
# 20
# [<picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/s/7/large/TUNE-AUDIO-U-I-NICE-SDL318619575-1-61a43.JPG" title="TUNE AUDIO U&amp;I NICE SERIES  12 HOURS MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic FOR OPPO,VIVO,MI,BOAT,JBL,SONY,ONEPLUS,BOAT"/>
# <img class="product-image" src="https://n3.sdlcdn.com/imgs/j/s/7/230X258_sharpened/TUNE-AUDIO-U-I-NICE-SDL318619575-1-61a43.JPG" title="TUNE AUDIO U&amp;I NICE SERIES  12 HOURS MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic FOR OPPO,VIVO,MI,BOAT,JBL,SONY,ONEPLUS,BOAT"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/s/9/large/KDM-G2-SOLID-20-HRS-SDL722669597-1-c053a.jpeg" title="KDM G2 SOLID SERIES MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic wireless FOR OPPO,VIVO,BOAT,ONEPLUS,JBL,SONY,SAMSUNG"/>
# <img class="product-image" src="https://n3.sdlcdn.com/imgs/j/s/9/230X258_sharpened/KDM-G2-SOLID-20-HRS-SDL722669597-1-c053a.jpeg" title="KDM G2 SOLID SERIES MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic wireless FOR OPPO,VIVO,BOAT,ONEPLUS,JBL,SONY,SAMSUNG"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/s/i/large/TUNE-AUDIO-U-I-FIGHTER-SDL846489130-1-35b38.jpg" title="TUNE AUDIO U&amp;I FIGHTER 12 HOURS MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic FOR OPPO,VIVO,MI,BOAT,JBL,SONY,ONEPLUS,BOAT"/>
# <img class="product-image" src="https://n3.sdlcdn.com/imgs/j/s/i/230X258_sharpened/TUNE-AUDIO-U-I-FIGHTER-SDL846489130-1-35b38.jpg" title="TUNE AUDIO U&amp;I FIGHTER 12 HOURS MUSIC PLAYBACK IPX4 4D BASS SPORT Bluetooth headphone / Bluetooth earphone Magnetic FOR OPPO,VIVO,MI,BOAT,JBL,SONY,ONEPLUS,BOAT"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n1.sdlcdn.com/imgs/j/t/5/large/1-OnePlus-Nord-CE-5G-SDL380565116-1-3e188.jpg" title="1+ OnePlus Nord CE 5G Bumper Cases Maggzoo - Black Transparent Eagle Back Cover"/>
# <img class="product-image" src="https://n1.sdlcdn.com/imgs/j/t/5/230X258_sharpened/1-OnePlus-Nord-CE-5G-SDL380565116-1-3e188.jpg" title="1+ OnePlus Nord CE 5G Bumper Cases Maggzoo - Black Transparent Eagle Back Cover"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/i/f/x/large/OnePlus-7-Pro-Shock-Proof-SDL044079718-1-77712.jpg" title="OnePlus 7 Pro Shock Proof Case OnePlus - Black"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/i/f/x/230X258_sharpened/OnePlus-7-Pro-Shock-Proof-SDL044079718-1-77712.jpg" title="OnePlus 7 Pro Shock Proof Case OnePlus - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n1.sdlcdn.com/imgs/j/q/s/large/OnePlus-6-Flip-Cover-by-SDL769716093-1-64941.jpg" title="OnePlus 6 Flip Mobile Cover by NBOX - Blue"/>
# <img class="product-image lazy-load" data-src="https://n1.sdlcdn.com/imgs/j/q/s/230X258_sharpened/OnePlus-6-Flip-Cover-by-SDL769716093-1-64941.jpg" title="OnePlus 6 Flip Mobile Cover by NBOX - Blue"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n4.sdlcdn.com/imgs/j/a/8/large/OnePlus-7T-Plain-Cases-Wow-SDL109270917-1-24d7a.jpg" title="OnePlus 7T Plain Cases Wow Imagine - Transparent"/>
# <img class="product-image lazy-load" data-src="https://n4.sdlcdn.com/imgs/j/a/8/230X258_sharpened/OnePlus-7T-Plain-Cases-Wow-SDL109270917-1-24d7a.jpg" title="OnePlus 7T Plain Cases Wow Imagine - Transparent"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/r/r/large/OnePlus-9R-Hybrid-Covers-NBOX-SDL804051370-1-248f1.jpg" title="OnePlus 9R Hybrid Transparent Mobile Cover by NBOX - Black"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/j/r/r/230X258_sharpened/OnePlus-9R-Hybrid-Covers-NBOX-SDL804051370-1-248f1.jpg" title="OnePlus 9R Hybrid Transparent Mobile Cover by NBOX - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n2.sdlcdn.com/imgs/g/m/n/large/OnePlus-OnePlus-5-Shock-Proof-SDL363675317-1-2463a.jpg" title="OnePlus OnePlus 5 Shock Proof Case Bracevor - Black"/>
# <img class="product-image lazy-load" data-src="https://n2.sdlcdn.com/imgs/g/m/n/230X258_sharpened/OnePlus-OnePlus-5-Shock-Proof-SDL363675317-1-2463a.jpg" title="OnePlus OnePlus 5 Shock Proof Case Bracevor - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n4.sdlcdn.com/imgs/j/u/b/large/renewed-earbuds-renewed-earbuds-renewed-SDL646285399-1-08c30.jpeg" title="renewed earbuds renewed earbuds renewed earbuds renewed earbuds ( CD-R ) - English"/>
# <img class="product-image lazy-load" data-src="https://n4.sdlcdn.com/imgs/j/u/b/230X258_sharpened/renewed-earbuds-renewed-earbuds-renewed-SDL646285399-1-08c30.jpeg" title="renewed earbuds renewed earbuds renewed earbuds renewed earbuds ( CD-R ) - English"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n1.sdlcdn.com/imgs/j/s/5/large/OnePlus-8T-Soft-Silicon-Cases-SDL902212718-1-d6672.jpg" title="OnePlus 8T Soft Silicon Cases MONDAL - Transparent &amp; Clear"/>
# <img class="product-image lazy-load" data-src="https://n1.sdlcdn.com/imgs/j/s/5/230X258_sharpened/OnePlus-8T-Soft-Silicon-Cases-SDL902212718-1-d6672.jpg" title="OnePlus 8T Soft Silicon Cases MONDAL - Transparent &amp; Clear"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n4.sdlcdn.com/imgs/j/t/x/large/1-OnePlus-Nord-CE-5G-SDL707424091-1-97ca4.jpg" title="1+ OnePlus Nord CE 5G Shock Proof Case JMA - Transparent Hybrid TPU Bumper Case"/>
# <img class="product-image lazy-load" data-src="https://n4.sdlcdn.com/imgs/j/t/x/230X258_sharpened/1-OnePlus-Nord-CE-5G-SDL707424091-1-97ca4.jpg" title="1+ OnePlus Nord CE 5G Shock Proof Case JMA - Transparent Hybrid TPU Bumper Case"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/h/3/g/large/OnePlus-6T-Soft-Silicon-Cases-SDL035692834-2-f55bd.png" title="OnePlus 6T Soft Silicon Cases O4U - Transparent"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/h/3/g/230X258_sharpened/OnePlus-6T-Soft-Silicon-Cases-SDL035692834-2-f55bd.png" title="OnePlus 6T Soft Silicon Cases O4U - Transparent"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n1.sdlcdn.com/imgs/j/u/b/large/oneplus-buds-bluetooth-oneplus-buds-SDL311261252-1-a8c1c.jpeg" title="oneplus buds bluetooth	oneplus buds bluetooth	oneplus buds bluetooth ( 3D ) - English"/>
# <img class="product-image lazy-load" data-src="https://n1.sdlcdn.com/imgs/j/u/b/230X258_sharpened/oneplus-buds-bluetooth-oneplus-buds-SDL311261252-1-a8c1c.jpeg" title="oneplus buds bluetooth	oneplus buds bluetooth	oneplus buds bluetooth ( 3D ) - English"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/q/m/large/OnePlus-Nord-Hybrid-Covers-NBOX-SDL598819865-1-79958.jpg" title="OnePlus Nord Hybrid Transparent Mobile Cover by NBOX - Black"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/j/q/m/230X258_sharpened/OnePlus-Nord-Hybrid-Covers-NBOX-SDL598819865-1-79958.jpg" title="OnePlus Nord Hybrid Transparent Mobile Cover by NBOX - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n2.sdlcdn.com/imgs/j/p/x/large/OnePlus-Nord-Flip-Cover-by-SDL127829793-1-0d107.png" title="OnePlus Nord Flip Cover by XORB - Brown"/>
# <img class="product-image lazy-load" data-src="https://n2.sdlcdn.com/imgs/j/p/x/230X258_sharpened/OnePlus-Nord-Flip-Cover-by-SDL127829793-1-0d107.png" title="OnePlus Nord Flip Cover by XORB - Brown"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/q/m/large/OnePlus-8-Hybrid-Covers-NBOX-SDL278500448-1-fa9c7.jpg" title="OnePlus 8 Hybrid Transparent Mobile Cover by NBOX - Black"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/j/q/m/230X258_sharpened/OnePlus-8-Hybrid-Covers-NBOX-SDL278500448-1-fa9c7.jpg" title="OnePlus 8 Hybrid Transparent Mobile Cover by NBOX - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/g/s/c/large/OnePlus-3-T-Shock-Proof-SDL799837864-1-2a9fd.jpg" title="OnePlus 3 T Shock Proof Case Bracevor - Transparent"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/g/s/c/230X258_sharpened/OnePlus-3-T-Shock-Proof-SDL799837864-1-2a9fd.jpg" title="OnePlus 3 T Shock Proof Case Bracevor - Transparent"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n3.sdlcdn.com/imgs/j/p/w/large/OnePlus-Nord-Bumper-Cases-Wow-SDL475719639-1-6e19d.jpg" title="OnePlus Nord Bumper Cases Wow Imagine - Black"/>
# <img class="product-image lazy-load" data-src="https://n3.sdlcdn.com/imgs/j/p/w/230X258_sharpened/OnePlus-Nord-Bumper-Cases-Wow-SDL475719639-1-6e19d.jpg" title="OnePlus Nord Bumper Cases Wow Imagine - Black"/>
# </picture>, <picture class="picture-elem">
# <source class="product-image" media="(min-width: 1430px)" srcset="https://n1.sdlcdn.com/imgs/j/l/i/large/OnePlus-Nord-Flip-Cover-by-SDL452455572-1-70bdf.jpg" title="OnePlus Nord Flip Cover by Shining Stars - Blue Viewing Stand and pocket"/>
# <img class="product-image lazy-load" data-src="https://n1.sdlcdn.com/imgs/j/l/i/230X258_sharpened/OnePlus-Nord-Flip-Cover-by-SDL452455572-1-70bdf.jpg" title="OnePlus Nord Flip Cover by Shining Stars - Blue Viewing Stand and pocket"/>
# </picture>]

# %%
picture.img.attrs['src']
# Out:
# 'https://n3.sdlcdn.com/imgs/j/s/7/230X258_sharpened/TUNE-AUDIO-U-I-NICE-SDL318619575-1-61a43.JPG'

# %%
img_url = picture.img.attrs['src']

with open('snap.jpg', 'wb') as file:
    
    response = requests.get(img_url)
    
    file.write(response.content)

# %%
for i, picture in enumerate(picture_element):
    try: 
        os.mkdir(input_str)
        with open('{}/{}-{}.jpg'.format(input_str, input_str, i), 'wb') as file:
            try:
                img_url = picture.img.attrs['src']
                response = requests.get(img_url)
                file.write(response.content)
            except KeyError:
                img_url = picture.img.attrs['data-src']
                response = requests.get(img_url)
                file.write(response.content)
    except FileExistsError:
        for f in os.listdir(input_str):
            os.remove(os.path.join(input_str, f))
        os.rmdir(input_str)
        with open('{}-{}.jpg'.format(input_str, i), 'wb') as file:
            try:
                img_url = picture.img.attrs['src']
                response = requests.get(img_url)
                file.write(response.content)
            except KeyError:
                img_url = picture.img.attrs['data-src']
                response = requests.get(img_url)
                file.write(response.content)
