# %% [markdown]
# # Quickstarter - Data Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,2,3,4,5])
y = x**2 + 3

# %%
plt.style.use('seaborn')

# %%
print(x,y)
# Out:
# [1 2 3 4 5] [ 4  7 12 19 28]

# %%
plt.plot(x,x**2 + x, label="Value 1")
plt.plot(x,x**2, label="value 2")
plt.title("Imported CSV")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.style.use('dark_background')

# %%
plt.scatter(x,x**2 + x, label="Stock Price 1")
plt.scatter(x,x**2, label="Stock Price 2")
plt.title("My Scatter Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.legend()
plt.show()
