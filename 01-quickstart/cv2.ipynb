# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('bike.jpg')
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
# Out:
# (2832, 4917, 3)

# %%
plt.imshow(rgb_image)
#plt.axis("off")
plt.show()

# %%
plt.imshow(rgb_image)
#plt.axis("off")
plt.show()

# %%
number_plate = rgb_image[1400:1780,600:1100,:]
plt.axis("off")
plt.imshow(number_plate)
plt.show()

# %%
total_pixels = crop_image.shape[0]*crop_image.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eff440d1e75e> in <module>
# ----> 1 total_pixels = crop_image.shape[0]*crop_image.shape[1]
#
# NameError: name 'crop_image' is not defined

# %%
print(total_pixels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-22a86b8e14fe> in <module>
# ----> 1 print(total_pixels)
#
# NameError: name 'total_pixels' is not defined

# %%
#Resize The Image

# %%
crop_image = cv2.resize(number_plate, (100,100))
plt.imshow(crop_image)
plt.axis("off")
plt.title("Resized Number Plate" + str(crop_image.shape))
plt.show()
